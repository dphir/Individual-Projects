# %% [raw]
# # Load the Excel file
#
# sheets = pd.read_excel(r'D:\KULIAH\SEMESTER 2\Operation Supply Chain Management\Week 6\Online Class\Project data\Selver.xlsx', sheet_name=All)
#
# # List to store all data
# all_data = []
#
# # Iterate over the sheets
# for sheet_name, df in sheets.items():
#     # Iterate through each column that contains combined data
#     for column in df.columns:
#         # Only split columns that contain '|' (indicating they need to be split)
#         if df[column].dtype == 'object':  # Check if the column is of string type
#             # Apply split and ensure 3 values per row, if not, fill with NaN
#             df[column] = df[column].apply(lambda x: x.split('|') if isinstance(x, str) and '|' in x else [None, None, None])
#
#     # Now, expand the list into multiple columns
#     # We will make sure the length of the lists is 3, and if not, we'll pad with None
#     expanded_data = pd.DataFrame(df[column].tolist(), columns=["Store Name", "Hours", "Address"])
#
#     # Concatenate this sheet's data to the all_data list
#     all_data.append(expanded_data)
#
# # Now concatenate all sheets into one DataFrame
# merged_data = pd.concat(all_data, ignore_index=True)
#
# # Optionally, save the merged data to a new file
# merged_data.to_excel('consolidated_data.xlsx', index=False)  # Save as Excel
#
# # Display the first few rows of the merged DataFrame
# merged_data.head()

# %% [raw]
# import pandas as pd
# from geopy.geocoders import Nominatim
# from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
# import time
#
# # Initialize Nominatim geolocator with a unique user agent
# geolocator = Nominatim(user_agent="coop_locator_by_dphir", timeout=60)
#
# # Caching the addresses to avoid re-geocoding the same address
# address_cache = {}
#
# # Function to get coordinates, with caching
# def get_coordinates_cached(address):
#     if address in address_cache:
#         # If the address is already cached, return cached result
#         return address_cache[address]
#
#     try:
#         location = geolocator.geocode(f"{address}, Estonia")
#         if location:
#             coords = (location.latitude, location.longitude)
#         else:
#             coords = (None, None)
#     except (GeocoderTimedOut, GeocoderUnavailable, Exception) as e:
#         print(f"Error for {address}: {e}")
#         coords = (None, None)
#
#     # Store the result in the cache
#     address_cache[address] = coords
#     return coords
#
# # Add Latitude and Longitude columns to the DataFrame
# df["Latitude"] = None
# df["Longitude"] = None
#
# # Loop through each row to get coordinates
# for idx, row in df.iterrows():
#     # Fetch the coordinates using the cached function
#     lat, lon = get_coordinates_cached(row["Address"])
#
#     # Update the DataFrame with coordinates
#     df.at[idx, "Latitude"] = lat
#     df.at[idx, "Longitude"] = lon
#
#     # Sleep to respect Nominatim's rate limit (1 second per request)
#     time.sleep(1)
#
# # Save the updated DataFrame to a new Excel file
# df.to_excel("updated_coop_estonia_stores.xlsx", index=False)
#
# # Print the resulting DataFrame to verify
# print(df.head())

# %% [raw]
# import math
#
# def geographic_midpoint(coordinates):
#     """
#     Calculate the geographic midpoint (centroid) from a list of (lat, lon) coordinates.
#     Returns (mid_lat, mid_lon) in decimal degrees.
#     """
#     # Convert degrees to radians and compute Cartesian coordinates
#     x_total, y_total, z_total = 0, 0, 0
#     for lat, lon in coordinates:
#         lat_rad = math.radians(lat)
#         lon_rad = math.radians(lon)
#         x_total += math.cos(lat_rad) * math.cos(lon_rad)
#         y_total += math.cos(lat_rad) * math.sin(lon_rad)
#         z_total += math.sin(lat_rad)
#
#     # Average the Cartesian coordinates
#     n = len(coordinates)
#     avg_x = x_total / n
#     avg_y = y_total / n
#     avg_z = z_total / n
#
#     # Convert back to latitude/longitude (radians)
#     lon_rad = math.atan2(avg_y, avg_x)
#     hyp = math.sqrt(avg_x**2 + avg_y**2)
#     lat_rad = math.atan2(avg_z, hyp)
#
#     # Convert to degrees
#     mid_lat = math.degrees(lat_rad)
#     mid_lon = math.degrees(lon_rad)
#     return (mid_lat, mid_lon)
#
# # Extract coordinates as a list of tuples
# outlets = list(zip(merged_data["latitude"], merged_data["longitude"]))
#
# # Calculate midpoint
# warehouse_lat, warehouse_lon = geographic_midpoint(outlets)
# print(f"Optimal Warehouse Location: {warehouse_lat:.6f}, {warehouse_lon:.6f}")

# %%
import pandas as pd

# %%
# Load the Excel file

df = pd.read_excel(r'D:\KULIAH\SEMESTER 2\Operation Supply Chain Management\Week 6\Online Class\project data\Selver.xlsx', sheet_name='All')

# %%
df.shape
# Out:
# (72, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Store Name  72 non-null     object
#  1   Address     72 non-null     object
#  2   Latitude    72 non-null     float64
#  3   Longitude   72 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 2.4+ KB

# %%
df.describe()
# Out:
#         Latitude  Longitude
# count  72.000000  72.000000
# mean   59.000181  25.281771
# std     0.523934   1.140859
# min    57.777500  22.486100
# 25%    58.384600  24.665475
# 50%    59.357350  24.776050
# 75%    59.436225  26.364975
# max    59.509200  28.179700

# %%
df.head()
# Out:
#                 Store Name                            Address  Latitude  \
# 0          Arsenali Selver        Erika tn 14, Tallinn, 10416   59.4410
# 1   Balti jaama Selver ABC    Toompuiestee 37, Tallinn, 10149   59.4385
# 2  Balti jaama turu Selver            Kopli 1, Tallinn, 10412   59.4380
# 3             Järve Selver  Pärnu maantee 238, Tallinn, 11624   59.3933
# 4            Kadaka Selver     Kadaka tee 56a, Tallinn, 12915   59.4124
#
#    Longitude
# 0    24.7280
# 1    24.7360
# 2    24.7365
# 3    24.7202
# 4    24.6673

# %% [markdown]
# References
#
# https://medium.com/@twalkb29/python-warehouse-optimization-unsupervised-ml-project-d92a9bc69c52
#
# https://medium.com/@genedarocha/133-optimizing-warehouse-operations-using-python-and-ai-3fe36412bfd2

# %%
df.columns
# Out:
# Index(['Store Name', 'Address', 'Latitude', 'Longitude'], dtype='object')

# %% [markdown]
# ### **Python Code to Find the Geographic Midpoint (Warehouse Location)**

# %%
# Convert to list of (latitude, longitude) tuples
coords = list(zip(df['Latitude'], df['Longitude']))

print(coords)
# Out:
# [(59.441, 24.728), (59.4385, 24.736), (59.438, 24.7365), (59.3933, 24.7202), (59.4124, 24.6673), (59.4374, 24.754), (59.4282, 24.627), (59.4415, 24.712), (59.428, 24.728), (59.4369, 24.7451), (59.448, 24.88), (59.353, 24.6283), (59.4362, 24.7471), (59.4529, 24.8747), (59.4224, 24.6972), (59.438, 24.698), (59.45, 24.88), (59.394, 24.685), (59.4385, 24.713), (59.47, 24.83), (59.45, 24.89), (59.437, 24.728), (59.43, 24.66), (59.421, 24.799), (59.4215, 24.799), (59.4145, 24.7421), (59.4281, 24.7482), (59.45, 24.88), (59.4363, 24.7387), (58.3636, 26.7137), (58.3824, 26.7115), (58.3843, 26.7258), (58.3819, 26.7094), (58.3742, 26.7051), (58.3869, 26.7336), (58.3686, 26.7046), (58.3905, 26.6844), (58.3697, 26.7207), (58.3745, 26.7128), (59.3796, 28.179), (58.3639, 25.5944), (58.8725, 22.5833), (58.7489, 26.3931), (59.3586, 27.4123), (57.8489, 26.9931), (59.3033, 24.4139), (59.3986, 27.2731), (59.3511, 26.3556), (59.355, 24.889), (58.3833, 24.5139), (59.3947, 24.2342), (58.3742, 24.5131), (58.3633, 25.5975), (58.3789, 24.5123), (58.885, 25.56), (59.3933, 24.8544), (58.6525, 25.97), (58.0611, 27.0694), (58.385, 24.4975), (58.3911, 26.7522), (58.3847, 24.5183), (58.9392, 23.5411), (58.9997, 24.7981), (58.2522, 22.4861), (59.3025, 24.6575), (58.385, 24.495), (59.4375, 24.5375), (57.7775, 26.0475), (58.3842, 24.4958), (59.3561, 24.645), (59.5092, 24.8306), (59.3792, 28.1797)]

# %%
# calculate geometric point

def calculate_geometric_midpoint(coords):
    lat_sum = sum(coord[0] for coord in coords)
    lon_sum = sum(coord[1] for coord in coords)
    num_points = len(coords)
    return (lat_sum / num_points, lon_sum / num_points)

midpoint = calculate_geometric_midpoint(coords)
print("Geometric Midpoint:", midpoint)
# Out:
# Geometric Midpoint: (59.00018055555555, 25.281770833333333)

# %% [markdown]
# ### **Python Code to Find the Warehouse Location**

# %%
import math

# midpoint
mid_lat = 59.00018055555555
mid_lon = 25.281770833333333

# Define spherical law of cosines function
def spherical_distance(lat1, lon1, lat2, lon2):
    lat1_rad = math.radians(90 - lat1)
    lat2_rad = math.radians(90 - lat2)
    lon_diff_rad = math.radians(lon2 - lon1)

    cos_d = (math.cos(lat1_rad) * math.cos(lat2_rad) +
             math.sin(lat1_rad) * math.sin(lat2_rad) * math.cos(lon_diff_rad))
    d = math.acos(cos_d) * 6371  # Radius of Earth in km
    return d


# Apply distance function for each store in KM (Kilometers)
df['Distance_to_Warehouse'] = df.apply(
    lambda row: spherical_distance(mid_lat, mid_lon, row['Latitude'], row['Longitude']),
    axis=1
)

# Round to 2 decimal places for neatness
df['Distance_to_Warehouse'] = df['Distance_to_Warehouse'].round(2)

df.head()
# Out:
#                 Store Name                            Address  Latitude  \
# 0          Arsenali Selver        Erika tn 14, Tallinn, 10416   59.4410
# 1   Balti jaama Selver ABC    Toompuiestee 37, Tallinn, 10149   59.4385
# 2  Balti jaama turu Selver            Kopli 1, Tallinn, 10412   59.4380
# 3             Järve Selver  Pärnu maantee 238, Tallinn, 11624   59.3933
# 4            Kadaka Selver     Kadaka tee 56a, Tallinn, 12915   59.4124
#
#    Longitude  Distance_to_Warehouse
# 0    24.7280                  58.27
# 1    24.7360                  57.79
# 2    24.7365                  57.73
# 3    24.7202                  54.16
# 4    24.6673                  57.66

# %%
# Export data to excel and save it

df.to_excel(r'D:\KULIAH\SEMESTER 2\Operation Supply Chain Management\Week 6\Online Class\Project data\selver_distances_to_warehouse.xlsx',index=False)

# %% [markdown]
# ### **Calculate Total and Average Distance**

# %%
# Calculate Total and Average Distance

total_distance = df['Distance_to_Warehouse'].sum()
average_distance = df['Distance_to_Warehouse'].mean()

print(f"Total distance from all stores to warehouse: {total_distance:.2f} km")
print(f"Average distance to warehouse: {average_distance:.2f} km")
# Out:
# Total distance from all stores to warehouse: 5738.09 km
# Average distance to warehouse: 79.70 km

# %% [markdown]
# ### **Find Closest and Farthest Stores**

# %%
closest_store = df.loc[df['Distance_to_Warehouse'].idxmin()]
farthest_store = df.loc[df['Distance_to_Warehouse'].idxmax()]

print(f"Closest store: {closest_store['Store Name']} - {closest_store['Distance_to_Warehouse']:.2f} km")
print(f"Farthest store: {farthest_store['Store Name']} - {farthest_store['Distance_to_Warehouse']:.2f} km")
# Out:
# Closest store: Paide Selver - 20.46 km
# Farthest store: Saare Selver - 181.94 km

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# Step 4.1: Summary statistics
print("Summary of distances (km):")
print(df['Distance_to_Warehouse'].describe())

# Step 4.2: Histogram of distances
plt.figure(figsize=(10, 5))
sns.histplot(df['Distance_to_Warehouse'], kde=True, bins=10, color='skyblue')
plt.title('Distribution of Distances to Warehouse')
plt.xlabel('Distance (km)')
plt.ylabel('Number of Stores')
plt.grid(True)
plt.show()

# Step 4.3: Map Visualization using Folium
# Create map centered on the warehouse
m = folium.Map(location=[mid_lat, mid_lon], zoom_start=11)

# Add warehouse marker
folium.Marker(
    location=[mid_lat, mid_lon],
    popup="Warehouse",
    icon=folium.Icon(color='red', icon='home')
).add_to(m)

# Add store markers
for _, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Store Name']} ({row['Distance_to_Warehouse']} km)",
        icon=folium.Icon(color='blue', icon='shopping-cart')
    ).add_to(m)

# Show the map
m.save("warehouse_store_map.html")
m
# Out:
# Summary of distances (km):
# count     72.000000
# mean      79.695694
# std       35.262604
# min       20.460000
# 25%       56.195000
# 50%       60.160000
# 75%      107.395000
# max      181.940000
# Name: Distance_to_Warehouse, dtype: float64
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fd3e9f71e382d3107c6f5ed025e22d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fd3e9f71e382d3107c6f5ed025e22d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fd3e9f71e382d3107c6f5ed025e22d6 = L.map(
#                 &quot;map_9fd3e9f71e382d3107c6f5ed025e22d6&quot;,
#                 {
#                     center: [59.00018055555555, 25.281770833333333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3198df182ccec145ee8d4b2a503332c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3198df182ccec145ee8d4b2a503332c.addTo(map_9fd3e9f71e382d3107c6f5ed025e22d6);
#
#
#             var marker_175b8105100e1a56904352408c3c6817 = L.marker(
#                 [59.00018055555555, 25.281770833333333],
#                 {
# }
#             ).addTo(map_9fd3e9f71e382d3107c6f5ed025e22d6);
#
#
#             var icon_5bf2705f444849e60a254a22ec515c04 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_111676c6c01310c244417669aecd39a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6d46c89fa41fb230d20b31d177fd9c8 = $(`&lt;div id=&quot;html_e6d46c89fa41fb230d20b31d177fd9c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Warehouse&lt;/div&gt;`)[0];
#                 popup_111676c6c01310c244417669aecd39a8.setContent(html_e6d46c89fa41fb230d20b31d177fd9c8);
#
#
#
#         marker_175b8105100e1a56904352408c3c6817.bindPopup(popup_111676c6c01310c244417669aecd39a8)
#         ;
#
#
#
#
#                 marker_175b8105100e1a56904352408c3c6817.setIcon(icon_5bf2705f444849e60a254a22ec515c04);
#
#
#             var marker_c4bac40e814e5ec7a7af22fef48859ed = L.marker(
#                 [59.441, 24.728],
#                 {
# }
#             ).addTo(map_9fd3e9f71e382d3107c6f5ed025e22d6);
#
#
#             var icon_7cf09d393052b1014c0770b3f839794d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;shopping-cart&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b82385dd6569790767cf5ed89d874fe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0156d6fc1d3f01c589889525c7f8bc1 = $(`&lt;div id=&quot;html_e0156d6fc1d3f01c589889525c7f8bc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arsenali Selver (58.27 km)&lt;/div&gt;`)[0];
#                 popup_b82385dd6569790767cf5ed89d874fe4.setContent(html_e0156d6fc1d3f01c589889525c7f8bc1);
#
#
#
#         marker_c4bac40e814e5ec7a7af22fef48859ed.bindPopup(popup_b82385dd6569790767cf5ed89d874fe4)
#         ;
#
#
#
#
#                 marker_c4bac40e814e5ec7a7af22fef48859ed.setIcon(icon_7cf09d393052b1014c0770b3f839794d);
#
#
#             var marker_8df4668a21a3651015acfd8d1e4a8381 = L.marker(
#                 [59.4385, 24.736],
#                 {
# }
#             ).addTo(map_9fd3e9f71e382d3107c6f5ed025e22d6);
#
#
#             var icon_f460ee4910a65f956b18388cb5d48700 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;shopping-cart&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d21a07cbd811df70101e1d034e8b2557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d6f37a87b9fb8b8a3c909d47842ee6d = $(`&lt;div id=&quot;html_5d6f37a87b9fb8b8a3c909d47842ee6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Balti jaama Selver ABC (57.79 km)&lt;/div&gt;`)[0];
#                 popup_d21a07cbd811df70101e1d034e8b2557.setContent(html_5d6f37a87b9fb8b8a3c909d47842ee6d);
#
#
#
#         marker_8df4668a21a3651015acfd8d1e4a8381.bindPopup(popup_d21a07cbd811df70101e1d034e8b2557)
#         ;
#
#
#
#
#                 marker_8df4668a21a3651015acfd8d1e4a8381.setIcon(icon_f460ee4910a65f956b18388cb5d48700);
#
#
#             var marker_f012ef44368fb0c4cef4a79578938c8c = L.marker(
#                 [59.438, 24.7365],
#                 {
# }
#             ).addTo(map_9fd3e9f71e382d3107c6f5ed025e22d6);
#
#
#             var icon_ba43ea86

# %% [markdown]
# ## **Justification for Warehouse Location (Geometric Midpoint)**
#
# Our team selected the warehouse location based on the geometric midpoint of all **72 store locations**, calculated at **latitude 59.0002 and longitude 25.2818.**
#
# Based on distance analysis:
#
# **The average distance** from the warehouse to the stores is approximately **79.70 km.**
#
# **The closest store is Paide Selver, located 20.46 km away.**
#
# **The farthest store is Saare Selver, located 181.94 km away.**
#
# These findings indicate that the chosen location is strategically positioned to serve all stores efficiently. The relatively moderate range between the nearest and farthest outlets supports the suitability of the geometric midpoint. It helps minimize total travel distances, potentially reducing both transportation costs and delivery times, making it a balanced and optimal location for the warehouse.
